# %%
import pandas as pd
import re
import json
import time as tm
from datetime import datetime
from oauth2client.service_account import ServiceAccountCredentials
from gcloud import storage
from ftplib import FTP
from glob import glob

def uploadjson(file, filename):
    credentials_dict = {
        'type': 'service_account',
        'client_id': "110677326745099597758",
        'client_email': 'cna-flask-project@appspot.gserviceaccount.com',
        'private_key_id': 'afc2c0eb7f067837400bf1dfa2b7d9db8efc5d80',
        'private_key': "-----BEGIN PRIVATE KEY-----\\nrkrBvrVGAUzsucEHGcfyDt8i\n-----END PRIVATE KEY-----\n",
    }
    credentials = ServiceAccountCredentials.from_json_keyfile_dict(
        credentials_dict
    )
    client = storage.Client(credentials=credentials, project='cna-flask-project')
    bucket = client.get_bucket('cna-flask-project.appspot.com')
    blob = bucket.blob('2020recall/{}.json'.format(filename))
    blob.upload_from_string(file, content_type='application/json')

# %%
with open('RFrunning.json','r') as json_file:
    final = json.load(json_file)
df = pd.DataFrame.from_dict(final['F1'],orient='columns')
df = df.loc[[0]]
time = (final['ST'])
df['time'] = time
df
# Out:
#   prvCode cityCode deptCode  tboxNo  agreeTks  agreeRate  disagreeTks  \
# 0      00      000      000       0   5856179      46.39      6768922
#
#    disagreeRate adptVictor     prof1  ...    prof6     prof7  profRate  \
# 0         53.61          N  12625101  ...  6119635  19128753     67.97
#
#    deptTot  deptRcv  tboxTot  tboxRcv  ytpRate  prgRate        time
# 0      368      368    17649    17649    30.61    100.0  0928145113
#
# [1 rows x 24 columns]

# %%
df = df[['prgRate','agreeTks', 'agreeRate', 'disagreeTks', 'disagreeRate','adptVictor','time']]
df.rename(columns = {'prgRate':'processRage', 'agreeTks':'agreeTicket','agreeRate':'agreeRat','disagreeTks':'disagreeTicket','disagreeRate':'disgreeRat', 'adptVictor':'pass'}, inplace = True)
df
# Out:
# C:\Users\apuser\AppData\Local\Temp\ipykernel_11616\1116963283.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns = {'prgRate':'processRage', 'agreeTks':'agreeTicket','agreeRate':'agreeRat','disagreeTks':'disagreeTicket','disagreeRate':'disgreeRat', 'adptVictor':'pass'}, inplace = True)
#    processRage  agreeTicket  agreeRat  disagreeTicket  disgreeRat pass  \
# 0        100.0      5856179     46.39         6768922       53.61    N
#
#          time
# 0  0928145113

# %%
while 'data/RFfinal.json' not in glob('data/*.json'):
    loopbegin = datetime.now()
    print('======================='+loopbegin.strftime("%H:%M"))
    with open('data/RFrunning.json','r') as json_file:
        data = json.load(json_file)

    a = [i for i in data['F1']][0] #if prvCode == '00' and i['cityCode'] =='000' and i['deptCode']=='000'][0]
    with open('data/progress_F.json','w') as f:
        json.dump(a, f)

    file_path = 'progress_F.json'
    with FTP('demo.cna.com.tw','u0401006','capo4188') as ftp, open('data/'+file_path, 'rb') as file:
        ftp.cwd('/20200815/api')
        ftp.storbinary(f'STOR {file_path}', file)
#     with FTP('172.17.242.151','20090948','u0401006@CNA123') as ftp, open(f'data/'+ file_path, 'rb') as file:
#         ftp.cwd('/20200605-recallvote/data')
#         ftp.storbinary(f'STOR {file_path}', file)
#     with FTP('210.69.89.186','20090948','u0401006@CNA123') as ftp, open('data/'+ file_path, 'rb') as file:
#         ftp.cwd('/20200605-recallvote/data')
#         ftp.storbinary(f'STOR {file_path}', file)

    print('now sleep {}s'.format(180-(datetime.now()-loopbegin).total_seconds()))
    tm.sleep(180-(datetime.now()-loopbegin).total_seconds())

with open('RFfinal.json','r') as json_file:
    final = json.load(json_file)
    a = [i for i in final['F1']][0]

    with open('data/progress_F.json','w') as f:
        json.dump(a, f)    
    file_path = 'progress_F.json'
    with FTP('demo.cna.com.tw','u0401006','capo4188') as ftp, open('data/'+file_path, 'rb') as file:
        ftp.cwd('/20200815/api')
        ftp.storbinary(f'STOR {file_path}', file)
#     with FTP('172.17.242.151','20090948','u0401006@CNA123') as ftp, open(f'data/'+ file_path, 'rb') as file:
#         ftp.cwd('/20200605-recallvote/data')
#         ftp.storbinary(f'STOR {file_path}', file)
#     with FTP('210.69.89.186','20090948','u0401006@CNA123') as ftp, open('data/'+ file_path, 'rb') as file:
#         ftp.cwd('/20200605-recallvote/data')
#         ftp.storbinary(f'STOR {file_path}', file)
# Out:
# ---------------------------------------------------------------------------
# error_perm                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22272\1245137217.py in <module>
#       8     file_path = 'progress_F.json'
#       9     with FTP('demo.cna.com.tw','u0401006','capo4188') as ftp, open('data/'+file_path, 'rb') as file:
# ---> 10         ftp.cwd('/20200815/api')
#      11         ftp.storbinary(f'STOR {file_path}', file)
#      12 #     with FTP('172.17.242.151','20090948','u0401006@CNA123') as ftp, open(f'data/'+ file_path, 'rb') as file:
#
# ~\anaconda3\lib\ftplib.py in cwd(self, dirname)
#     623             dirname = '.'  # does nothing, but could return error
#     624         cmd = 'CWD ' + dirname
# --> 625         return self.voidcmd(cmd)
#     626
#     627     def size(self, filename):
#
# ~\anaconda3\lib\ftplib.py in voidcmd(self, cmd)
#     284         """Send a command and expect a response beginning with '2'."""
#     285         self.putcmd(cmd)
# --> 286         return self.voidresp()
#     287
#     288     def sendport(self, host, port):
#
# ~\anaconda3\lib\ftplib.py in voidresp(self)
#     257     def voidresp(self):
#     258         """Expect a response beginning with '2'."""
# --> 259         resp = self.getresp()
#     260         if resp[:1] != '2':
#     261             raise error_reply(resp)
#
# ~\anaconda3\lib\ftplib.py in getresp(self)
#     252             raise error_temp(resp)
#     253         if c == '5':
# --> 254             raise error_perm(resp)
#     255         raise error_proto(resp)
#     256
#
# error_perm: 550 Can't change directory to /20200815/api: No such file or directory

# %%
import json
import time
import os
import shutil
from ftplib import FTP
from oauth2client.service_account import ServiceAccountCredentials
import gspread
from gspread_dataframe import get_as_dataframe, set_with_dataframe
import pandas as pd
from pandas import json_normalize

target_file = 'C:/Users/chi/OneDrive/桌面/公投api/RFfinal.json'

# %%
while os.path.exists(target_file) == False:
    loopbegin = time.time()
    t = time.ctime(loopbegin)
    print(t+'開始跑囉！')
    with open('C:/Users/chi/OneDrive/桌面/公投api/RFrunning.json') as j:
        data = json.load(j)
        # data['F1'][0]['prof7'] = 19880000
        new_data = {'F1': data['F1'][0]}

    with open('result.json', 'w', encoding='utf-8') as fp:
        json.dump(new_data, fp, ensure_ascii=False)
    #備份檔案 
    #shutil.copyfile('C:/Users/chi/OneDrive/桌面/公投api/RFrunning.json', f'C:/Users/chi/OneDrive/桌面/公投api/RFrunning{loopbegin}.json', follow_symlinks = True)
        
    #實體檔名，上傳時用
    file_path = 'result.json'
    with FTP('172.17.242.167', '20090948', 'u0401006@CNA123') as ftp, open(file_path, 'rb') as file:
        ftp.cwd('/20211122-referendum/api')
        ftp.storbinary(f'STOR {file_path}', file)
    with FTP('172.16.142.167', '20090948', 'u0401006@CNA123') as ftp, open(file_path, 'rb') as file:
        ftp.cwd('/20211122-referendum/api')
        ftp.storbinary(f'STOR {file_path}', file)

    print(f'{file_path} uploaded!')

    #休息時間
    duration = time.time()- loopbegin
    try:
        print(f'休息{int(180-duration)}秒，還沒結束ㄛ')
        time.sleep(int(180-duration))
    except:
        continue

# %%
#出現RFfinal檔後
with open(target_file) as j:
    data = json.load(j) #從json檔讀資料
    #把prof7改為固定數值
    data['F1'][0]['prof7'] = 19880000
    new_data = {'F1': data['F1'][0]}

with open('result.json', 'w', encoding='utf-8') as fp:
    json.dump(new_data, fp, ensure_ascii=False)

# #上傳final檔到即時開票
file_path = 'result.json'
with FTP('172.17.242.167', '20090948', 'u0401006@CNA123') as ftp, open(file_path, 'rb') as file:
    ftp.cwd('/20211122-referendum/api')
    ftp.storbinary(f'STOR {file_path}', file)
with FTP('172.16.142.167', '20090948', 'u0401006@CNA123') as ftp, open(file_path, 'rb') as file:
    ftp.cwd('/20211122-referendum/api')
    ftp.storbinary(f'STOR {file_path}', file)

loopbegin = time.time()
print(time.ctime(loopbegin))
print(f'{file_path} 即時資料完成')

#清洗資料
with open(target_file, encoding='utf-8') as d:
  data = json.loads(d.read())
f1 = json_normalize(data['F1'])
new_data = [f1]
#全國資料整理
result = pd.DataFrame(columns=['Code', 'agreeTks', 'agreeRate', 'disagreeTks', 'disagreeRate','ytpRate'])
for no,i in enumerate(new_data):
  #合併地區代碼
  i['Code'] = i['prvCode']+i['cityCode']+i['deptCode']
  i['disPercentage'] = i.apply(lambda x: x['disagreeTks'] / x['prof7'], axis=1)
  i['disPercentage'] = i['disagreeTks'] / i['prof7']
#選出我要的code值
  filter = i['Code'].isin(['10002000','10013000','10008000','09020000','10015000','10005000',
              '09007000','10017000','64000000','68000000','10009000','10020000',
              '10004000','10018000','65000000','10010000','67000000','10014000',
              '63000000','66000000','10007000','10016000'])
  new = i[filter]
  j = new.reindex(columns=['Code', 'agreeTks', 'agreeRate', 'ytpRate', 'disagreeTks', 'disagreeRate'])
  result = result.append(j)
write('1LobQFu_6JCiN0Z-dU-Yoe8M-m2V_Lf7niXb2CjVqSLc','全國', result)

loopbegin = time.time()
print(time.ctime(loopbegin))
print(f'各縣市資料都上傳囉！')
